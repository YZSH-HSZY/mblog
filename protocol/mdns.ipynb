# %% [markdown]
# ---
# Title: Description and Usage of the MDNS protocol.
# Date: 2024-04-01 12:00
# Lang: zh-cn
# Category: Protocol
# ---

# %% [markdown]
# # 介绍
#
# mDNS(RFC 6762 Multicast DNS, 组播DNS)和DNS-SD(RFC 6763 DNS-Based Service Discovery, 基于DNS的服务侦测)一般结合使用, 主要用于零配置网络下的资源发现.
